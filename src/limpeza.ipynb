# %% [markdown]
# # Realizando a limpeza de dados de todos os datasets- caso necessário

# %% [markdown]
# ## Link para o notebook principal

# %% [markdown]
# [Ir para main.ipynb](./main.ipynb)

# %% [markdown]
# ## Índice

# %% [markdown]
# - [Importando Pacotes e Bibliotecas](#importando-os-pacotes-e-bibliotecas)
# - [Importando os Datasets](#importando-os-datasets)
# - [Análise dos Datasets](#analise-inicial-dos-datasets)
#     - [Consumo Residencial por UF](#consumo-residencial-por-uf)

# %% [markdown]
# ## Importando Pacotes e Bibliotecas

# %%
## Impressao de Graficos
from matplotlib import pyplot as plt
import seaborn as sns

## Bibliotecas Base
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importando os datasets

# %%
df_residencial_raw = pd.read_csv("./databases/raw/CONSUMO MENSAL DE ENERGIA ELÉTRICA POR CLASSE - CONSUMO COMERCIAL POR UF.csv", sep = ",", index_col = 0)

# %% [markdown]
# ## Analise Inicial dos Datasets

# %% [markdown]
# ### Consumo Residencial por UF

# %%
df_residencial_raw.sample(10)
# Out:
#                                      Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# Empresa de Pesquisa Energética - EPE
# Mato Grosso                              64.699     65.905     74.538
# NaN                                         JAN        FEV        MAR
# Rio Grande do Norte                      41.973     37.909     41.133
# Paraíba                                  35.917     32.453     34.378
# Rio Grande do Sul                       276.902    285.451    283.818
# Paraná                                  257.033    269.481    268.151
# Rondônia                                 25.870     23.367     24.153
# Roraima                                   6.141      5.822      5.494
# Pará                                     78.075     72.467     75.857
# Ceará                                    95.718     86.036     90.007
#
#                                      Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# Empresa de Pesquisa Energética - EPE
# Mato Grosso                              77.146     68.100     61.587
# NaN                                         ABR        MAI        JUN
# Rio Grande do Norte                      43.495     41.067     41.715
# Paraíba                                  35.924     33.864     33.950
# Rio Grande do Sul                       297.774    266.991    245.687
# Paraná                                  275.652    267.628    239.079
# Rondônia                                 24.113     25.789     24.112
# Roraima                                   6.035      5.548      5.472
# Pará                                     78.779     79.714     82.470
# Ceará                                    97.130     90.758     93.769
#
#                                      Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# Empresa de Pesquisa Energética - EPE
# Mato Grosso                              66.190     62.202     69.190
# NaN                                         JUL        AGO        SET
# Rio Grande do Norte                      39.380     40.479     41.184
# Paraíba                                  32.155     31.641     35.194
# Rio Grande do Sul                       251.824    248.318    251.759
# Paraná                                  238.401    249.298    264.561
# Rondônia                                 24.312     25.604     25.980
# Roraima                                   5.876      5.820      5.652
# Pará                                     79.919     83.589     83.100
# Ceará                                    87.315     92.398     97.622
#
#                                      Unnamed: 10  ... Unnamed: 243  \
# Empresa de Pesquisa Energética - EPE              ...
# Mato Grosso                               72.326  ...      164.770
# NaN                                          OUT  ...          MAR
# Rio Grande do Norte                       42.784  ...       95.051
# Paraíba                                   34.712  ...       94.813
# Rio Grande do Sul                        248.016  ...      535.528
# Paraná                                   255.562  ...      702.042
# Rondônia                                  27.250  ...       64.375
# Roraima                                    5.980  ...       26.157
# Pará                                      82.032  ...      195.932
# Ceará                                     93.272  ...      198.606
#
#                                      Unnamed: 244 Unnamed: 245 Unnamed: 246  \
# Empresa de Pesquisa Energética - EPE
# Mato Grosso                               161.940          NaN          NaN
# NaN                                           ABR          MAI          JUN
# Rio Grande do Norte                        95.542          NaN          NaN
# Paraíba                                    96.817          NaN          NaN
# Rio Grande do Sul                         506.310          NaN          NaN
# Paraná                                    663.592          NaN          NaN
# Rondônia                                   67.186          NaN          NaN
# Roraima                                    26.730          NaN          NaN
# Pará                                      196.144          NaN          NaN
# Ceará                                     210.942          NaN          NaN
#
#                                      Unnamed: 247 Unnamed: 248 Unnamed: 249  \
# Empresa de Pesquisa Energética - EPE
# Mato Grosso                                   NaN          NaN          NaN
# NaN                                           JUL          AGO          SET
# Rio Grande do Norte                           NaN          NaN          NaN
# Paraíba                                       NaN          NaN          NaN
# Rio Grande do Sul                             NaN          NaN          NaN
# Paraná                                        NaN          NaN          NaN
# Rondônia                                      NaN          NaN          NaN
# Roraima                                       NaN          NaN          NaN
# Pará                                          NaN          NaN          NaN
# Ceará                                         NaN          NaN          NaN
#
#                                      Unnamed: 250 Unnamed: 251 Unnamed: 252
# Empresa de Pesquisa Energética - EPE
# Mato Grosso                                   NaN          NaN          NaN
# NaN                                           OUT          NOV          DEZ
# Rio Grande do Norte                           NaN          NaN          NaN
# Paraíba                                       NaN          NaN          NaN
# Rio Grande do Sul                             NaN          NaN          NaN
# Paraná                                        NaN          NaN          NaN
# Rondônia                                      NaN          NaN          NaN
# Roraima                                       NaN          NaN          NaN
# Pará                                          NaN          NaN          NaN
# Ceará                                         NaN          NaN          NaN
#
# [10 rows x 252 columns]

# %% [markdown]
# #### Quantidade de valores nulos

# %%
df_residencial_transposto = df_residencial_raw.transpose()
df_residencial_transposto.sample(10)
# Out:
# Empresa de Pesquisa Energética - EPE Consumo de energia elétrica na rede (MWh)  \
# Unnamed: 146                                                               NaN
# Unnamed: 152                                                               NaN
# Unnamed: 104                                                               NaN
# Unnamed: 70                                                                NaN
# Unnamed: 103                                                               NaN
# Unnamed: 130                                                               NaN
# Unnamed: 54                                                                NaN
# Unnamed: 137                                                               NaN
# Unnamed: 214                                                               NaN
# Unnamed: 84                                                                NaN
#
# Empresa de Pesquisa Energética - EPE Sistema SIMPLES  NaN  NaN  NaN  \
# Unnamed: 146                                     NaN  NaN  NaN  FEV
# Unnamed: 152                                     NaN  NaN  NaN  AGO
# Unnamed: 104                                     NaN  NaN  NaN  AGO
# Unnamed: 70                                      NaN  NaN  NaN  OUT
# Unnamed: 103                                     NaN  NaN  NaN  JUL
# Unnamed: 130                                     NaN  NaN  NaN  OUT
# Unnamed: 54                                      NaN  NaN  NaN  JUN
# Unnamed: 137                                     NaN  NaN  NaN  MAI
# Unnamed: 214                                     NaN  NaN  NaN  OUT
# Unnamed: 84                                      NaN  NaN  NaN  DEZ
#
# Empresa de Pesquisa Energética - EPE TOTAL POR UF Rondônia    Acre Amazonas  \
# Unnamed: 146                            7.714.336   52.199  19.568  106.846
# Unnamed: 152                            6.749.563   57.096  21.601  108.282
# Unnamed: 104                            6.303.157   55.764  16.380  102.290
# Unnamed: 70                             5.493.177   38.114  12.083   79.026
# Unnamed: 103                            6.033.383   46.728  15.582   97.478
# Unnamed: 130                            7.615.292   58.201  20.820  113.746
# Unnamed: 54                             4.829.191   30.951   9.594   63.604
# Unnamed: 137                            7.363.736   52.049  17.937  110.278
# Unnamed: 214                            7.489.159   61.321  24.266  126.744
# Unnamed: 84                             6.305.473   42.160  12.346   81.054
#
# Empresa de Pesquisa Energética - EPE Roraima  ... Rio de Janeiro  São Paulo  \
# Unnamed: 146                          16.653  ...        934.857  2.493.505
# Unnamed: 152                          17.422  ...        782.348  2.104.782
# Unnamed: 104                          11.844  ...        787.420  2.003.427
# Unnamed: 70                            9.774  ...        675.759  1.847.923
# Unnamed: 103                          11.424  ...        741.606  1.921.554
# Unnamed: 130                          16.590  ...        910.775  2.489.951
# Unnamed: 54                            7.791  ...        605.538  1.601.754
# Unnamed: 137                          15.060  ...        893.693  2.391.126
# Unnamed: 214                          21.978  ...        730.244  2.333.937
# Unnamed: 84                           10.205  ...        811.233  2.108.546
#
# Empresa de Pesquisa Energética - EPE   Paraná Santa Catarina  \
# Unnamed: 146                          531.939        381.380
# Unnamed: 152                          447.031        281.536
# Unnamed: 104                          426.382        269.386
# Unnamed: 70                           349.352        206.171
# Unnamed: 103                          393.085        255.819
# Unnamed: 130                          493.331        314.553
# Unnamed: 54                           316.489        192.114
# Unnamed: 137                          472.437        313.498
# Unnamed: 214                          515.523        357.982
# Unnamed: 84                           396.067        249.973
#
# Empresa de Pesquisa Energética - EPE Rio Grande do Sul Mato Grosso do Sul  \
# Unnamed: 146                                   481.190            107.263
# Unnamed: 152                                   366.845             90.689
# Unnamed: 104                                   381.650             80.760
# Unnamed: 70                                    314.549             62.423
# Unnamed: 103                                   373.098             69.974
# Unnamed: 130                                   420.819            108.230
# Unnamed: 54                                    300.483             47.330
# Unnamed: 137                                   417.410             95.276
# Unnamed: 214                                   363.072            101.138
# Unnamed: 84                                    387.416             75.344
#
# Empresa de Pesquisa Energética - EPE Mato Grosso    Goiás Distrito Federal  \
# Unnamed: 146                             141.607  189.318          166.111
# Unnamed: 152                             132.032  179.428          163.268
# Unnamed: 104                             112.079  159.762          155.833
# Unnamed: 70                               94.274  154.123          137.634
# Unnamed: 103                             113.124  166.904          150.683
# Unnamed: 130                             152.280  211.597          186.377
# Unnamed: 54                               81.021  139.509          114.039
# Unnamed: 137                             133.454  198.388          172.440
# Unnamed: 214                             156.992  228.171          174.649
# Unnamed: 84                               97.578  161.570          149.745
#
# Empresa de Pesquisa Energética - EPE Nota: atualização defasada para não antecipar informações de distribuidoras que devem obedecer às intruções da CVM sobre publicação de resultados.
# Unnamed: 146                                                                        NaN
# Unnamed: 152                                                                        NaN
# Unnamed: 104                                                                        NaN
# Unnamed: 70                                                                         NaN
# Unnamed: 103                                                                        NaN
# Unnamed: 130                                                                        NaN
# Unnamed: 54                                                                         NaN
# Unnamed: 137                                                                        NaN
# Unnamed: 214                                                                        NaN
# Unnamed: 84                                                                         NaN
#
# [10 rows x 34 columns]

# %%
columns_to_be_droped = [
    "Consumo de energia elétrica na rede (MWh)",
    "Sistema SIMPLES",
    "Nota: atualização defasada para não antecipar informações de distribuidoras que devem obedecer às intruções da CVM sobre publicação de resultados.",
    "TOTAL POR UF"
]

# %%
df_residencial_transposto.drop(columns = columns_to_be_droped, inplace = True, axis = "columns")
df_residencial_transposto.sample(10)
# Out:
# Empresa de Pesquisa Energética - EPE  NaN  NaN  NaN Rondônia    Acre Amazonas  \
# Unnamed: 185                          NaN  NaN  MAI   58.945  21.979  112.602
# Unnamed: 212                          NaN  NaN  AGO   57.865  21.508  155.641
# Unnamed: 79                               91.227  142.565          125.603
# Unnamed: 219                             165.366  220.280          169.714
# Unnamed: 31                               71.540   96.527           93.021
#
# [10 rows x 30 columns]

# %% [markdown]
# ## Renomeando colunas que não possuiam nomes

# %%
columns_to_rename = pd.Series(df_residencial_transposto.columns)
columns_to_rename = columns_to_rename.fillna("new_name" + (columns_to_rename.groupby(columns_to_rename.isnull()).cumcount() + 1).astype(str))
df_residencial_transposto.columns = columns_to_rename
df_residencial_transposto.sample(10)
# Out:
# Empresa de Pesquisa Energética - EPE new_name1 new_name2 new_name3 Rondônia  \
# Unnamed: 102                               NaN       NaN       JUN   49.920
# Unnamed: 252                               NaN       NaN       DEZ      NaN
# Unnamed: 151                               NaN       NaN       JUL   53.228
# Unnamed: 246                               NaN       NaN       JUN      NaN
# Unnamed: 99                                NaN       NaN       MAR   53.988
# Unnamed: 211                               NaN       NaN       JUL   53.407
# Unnamed: 27                                NaN       NaN       MAR   27.565
# Unnamed: 61                                NaN      2009       JAN   33.013
# Unnamed: 46                                NaN       NaN       OUT   33.185
# Unnamed: 42                                NaN       NaN       JUN   30.746
#
# Empresa de Pesquisa Energética - EPE    Acre Amazonas Roraima     Pará  \
# Unnamed: 102                          15.402   97.683  12.119  123.534
# Unnamed: 252                             NaN      NaN     NaN      NaN
# Unnamed: 151                          20.506  109.691  15.431  165.613
# Unnamed: 246                             NaN      NaN     NaN      NaN
# Unnamed: 99                           14.916   99.293  12.012  116.883
# Unnamed: 211                          18.721  118.203  19.082  175.964
# Unnamed: 27                            8.610   52.198   6.592   84.087
# Unnamed: 61                           10.485   64.356   8.406  100.483
# Unnamed: 46                           10.516   64.729   7.733   98.611
# Unnamed: 42                            8.845   63.666   7.022   95.474
#
# Empresa de Pesquisa Energética - EPE   Amapá Tocantins  ... Espírito Santo  \
# Unnamed: 102                          18.578    27.880  ...        132.348
# Unnamed: 252                             NaN       NaN  ...            NaN
# Unnamed: 151                          21.744    34.978  ...        128.671
# Unnamed: 246                             NaN       NaN  ...            NaN
# Unnamed: 99                           14.702    25.927  ...        149.114
# Unnamed: 211                          22.348    35.797  ...        127.647
# Unnamed: 27                            8.771    15.933  ...        103.277
# Unnamed: 61                           12.735    19.751  ...        113.663
# Unnamed: 46                           11.488    19.781  ...         99.490
# Unnamed: 42                           10.952    18.988  ...         95.068
#
# Empresa de Pesquisa Energética - EPE Rio de Janeiro  São Paulo   Paraná  \
# Unnamed: 102                                750.148  2.061.323  398.117
# Unnamed: 252                                    NaN        NaN      NaN
# Unnamed: 151                                770.328  2.126.062  442.577
# Unnamed: 246                                    NaN        NaN      NaN
# Unnamed: 99                                 869.194  2.302.532  474.064
# Unnamed: 211                                656.357  2.030.064  449.037
# Unnamed: 27                                 680.072  1.671.868  302.344
# Unnamed: 61                                 687.639  1.754.774  346.211
# Unnamed: 46                                 620.011  1.658.788  318.532
# Unnamed: 42                                 577.943  1.559.608  294.247
#
# Empresa de Pesquisa Energética - EPE Santa Catarina Rio Grande do Sul  \
# Unnamed: 102                                259.396           378.414
# Unnamed: 252                                    NaN               NaN
# Unnamed: 151                                282.047           374.636
# Empresa de Pesquisa Energética - EPE Maranhão  ... Espírito Santo  \
# Unnamed: 1                             40.478  ...         84.820
# Unnamed: 2                             37.893  ...         83.917
# Unnamed: 3                             40.878  ...         86.051
# Unnamed: 4                             40.503  ...         83.633
# Unnamed: 5                             42.202  ...         82.244
#
# Empresa de Pesquisa Energética - EPE Rio de Janeiro  São Paulo   Paraná  \
# Unnamed: 1                                  567.235  1.464.892  257.033
# Unnamed: 2                                  594.478  1.421.228  269.481
# Unnamed: 3                                  585.939  1.416.476  268.151
# Unnamed: 4                                  600.339  1.579.356  275.652
# Unnamed: 5                                  564.569  1.386.690  267.628
#
# Empresa de Pesquisa Energética - EPE Santa Catarina Rio Grande do Sul  \
# Unnamed: 1                                  170.067           276.902
# Unnamed: 2                                  178.963           285.451
# Unnamed: 3                                  186.488           283.818
# Unnamed: 4                                  170.145           297.774
# Unnamed: 5                                  161.961           266.991
#
# Empresa de Pesquisa Energética - EPE Mato Grosso do Sul Mato Grosso    Goiás  \
# Unnamed: 1                                       51.890      64.699   97.266
# Unnamed: 2                                       52.518      65.905   90.106
# Unnamed: 3                                       51.766      74.538   96.474
# Unnamed: 4                                       55.175      77.146  102.078
# Unnamed: 5                                       49.652      68.100   95.321
#
# Empresa de Pesquisa Energética - EPE Distrito Federal
# Unnamed: 1                                     93.427
# Unnamed: 2                                     81.618
# Unnamed: 3                                     84.322
# Unnamed: 4                                     94.761
# Unnamed: 5                                     90.165
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Preenchendo a coluna "ano" com valores corretos do ano

# %%
df_residencial_transposto["ano"] = df_residencial_transposto["ano"].ffill()

# %% [markdown]
# ## Transformando colunas importantes em Índice

# %%
df_residencial_transposto["ano"].unique()
# Out:
# array(['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022', '2023', '2024*'], dtype=object)

# %%
df_residencial_transposto["mes"].unique()
# Out:
# array(['JAN', 'FEV', 'MAR', 'ABR', 'MAI', 'JUN', 'JUL', 'AGO', 'SET',
#        'OUT', 'NOV', 'DEZ'], dtype=object)

# %%
df_residencial_transposto.columns
# Out:
# Index(['ano', 'mes', 'Rondônia', 'Acre', 'Amazonas', 'Roraima', 'Pará',
#        'Amapá', 'Tocantins', 'Maranhão', 'Piauí', 'Ceará',
#        'Rio Grande do Norte', 'Paraíba', 'Pernambuco', 'Alagoas', 'Sergipe',
#        'Bahia', 'Minas Gerais', 'Espírito Santo', 'Rio de Janeiro',
#        'São Paulo', 'Paraná', 'Santa Catarina', 'Rio Grande do Sul',
#        'Mato Grosso do Sul', 'Mato Grosso', 'Goiás', 'Distrito Federal'],
#       dtype='object', name='Empresa de Pesquisa Energética - EPE')

# %%
df_residencial_transposto.reset_index(inplace = True)
df_residencial_transposto["ano"] = df_residencial_transposto["ano"].astype("str")
df_residencial_transposto["mes"] = df_residencial_transposto["mes"].astype("str")
df_residencial_transposto.set_index(["ano", "mes"], inplace = True)
df_residencial_transposto.drop(columns = ["index"], axis = "columns", inplace = True)

# %%
df_residencial_transposto.sample(10)
# Out:
# Empresa de Pesquisa Energética - EPE Rondônia    Acre Amazonas Roraima  \
# ano  mes
# 2005 ABR                               26.397   7.587   55.001   6.593
# 2018 SET                               55.864  19.219  107.012  17.759
# 2005 MAI                               27.307   7.567   52.808   6.382
# 2010 MAR                               36.503  10.884   70.211   9.187
# 2013 NOV                               53.027  16.984  109.600  13.346
# 2016 ABR                               53.620  19.787  107.748  16.871
# 2017 SET                               59.221  24.179  103.601  17.756
# 2013 AGO                               50.027  15.395  108.376  12.683
#      FEV                                      165.747
#      MAR                                      174.415
#      ABR                                      172.290
#      MAI                                      161.071
#      JUN                                      163.329
#      JUL                                      156.604
#      AGO                                      163.675
#      SET                                      176.912
#      OUT                                      187.050
#      NOV                                      191.627
#      DEZ                                      188.911
#
# [20 rows x 27 columns]

# %% [markdown]
# ### Verificandos os tipos das colunas do dataset

# %%
df_residencial_processed.dtypes
# Out:
# Empresa de Pesquisa Energética - EPE
# Rondônia               object
# Acre                   object
# Amazonas               object
# Roraima                object
# Pará                   object
# Amapá                  object
# Tocantins              object
# Maranhão               object
# Piauí                  object
# Ceará                  object
# Rio Grande do Norte    object
# Paraíba                object
# Pernambuco             object
# Alagoas                object
# Sergipe                object
# Bahia                  object
# Minas Gerais           object
# Espírito Santo         object
# Rio de Janeiro         object
# São Paulo              object
# Paraná                 object
# Santa Catarina         object
# Rio Grande do Sul      object
# Mato Grosso do Sul     object
# Mato Grosso            object
# Goiás                  object
# Distrito Federal       object
# dtype: object

# %% [markdown]
# ### Trocando os tipos dos dados para melhor compressão e compreensão do dataset

# %% [markdown]
# Os dados serão trocados para o tipo "unsigned integer" de 32 bits

# %%
for coluna in df_residencial_processed.columns:
    df_residencial_processed[coluna] = [valor.replace(".", "") for valor in df_residencial_processed[coluna]]
# Out:
# /tmp/ipykernel_12865/1611594844.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed[coluna] = [valor.replace(".", "") for valor in df_residencial_processed[coluna]]

# %%
df_residencial_processed["Rondônia"] = df_residencial_processed["Rondônia"].astype("uint32")
df_residencial_processed["Acre"] = df_residencial_processed["Acre"].astype("uint32")
df_residencial_processed["Amazonas"] = df_residencial_processed["Amazonas"].astype("uint32")
df_residencial_processed["Roraima"] = df_residencial_processed["Roraima"].astype("uint32")
df_residencial_processed["Pará"] = df_residencial_processed["Pará"].astype("uint32")
df_residencial_processed["Amapá"] = df_residencial_processed["Amapá"].astype("uint32")
df_residencial_processed["Tocantins"] = df_residencial_processed["Tocantins"].astype("uint32")
df_residencial_processed["Maranhão"] = df_residencial_processed["Maranhão"].astype("uint32")
df_residencial_processed["Piauí"] = df_residencial_processed["Piauí"].astype("uint32")
df_residencial_processed["Ceará"] = df_residencial_processed["Ceará"].astype("uint32")
df_residencial_processed["Rio Grande do Norte"] = df_residencial_processed["Rio Grande do Norte"].astype("uint32")
df_residencial_processed["Paraíba"] = df_residencial_processed["Paraíba"].astype("uint32")
df_residencial_processed["Pernambuco"] = df_residencial_processed["Pernambuco"].astype("uint32")
df_residencial_processed["Alagoas"] = df_residencial_processed["Alagoas"].astype("uint32")
df_residencial_processed["Sergipe"] = df_residencial_processed["Sergipe"].astype("uint32")
df_residencial_processed["Bahia"] = df_residencial_processed["Bahia"].astype("uint32")
df_residencial_processed["Minas Gerais"] = df_residencial_processed["Minas Gerais"].astype("uint32")
df_residencial_processed["Espírito Santo"] = df_residencial_processed["Espírito Santo"].astype("uint32")
df_residencial_processed["Rio de Janeiro"] = df_residencial_processed["Rio de Janeiro"].astype("uint32")
df_residencial_processed["São Paulo"] = df_residencial_processed["São Paulo"].astype("uint32")
df_residencial_processed["Paraná"] = df_residencial_processed["Paraná"].astype("uint32")
df_residencial_processed["Santa Catarina"] = df_residencial_processed["Santa Catarina"].astype("uint32")
df_residencial_processed["Rio Grande do Sul"] = df_residencial_processed["Rio Grande do Sul"].astype("uint32")
df_residencial_processed["Mato Grosso do Sul"] = df_residencial_processed["Mato Grosso do Sul"].astype("uint32")
df_residencial_processed["Mato Grosso"] = df_residencial_processed["Mato Grosso"].astype("uint32")
df_residencial_processed["Goiás"] = df_residencial_processed["Goiás"].astype("uint32")
df_residencial_processed["Distrito Federal"] = df_residencial_processed["Distrito Federal"].astype("uint32")
# Out:
# /tmp/ipykernel_12865/3757876696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Rondônia"] = df_residencial_processed["Rondônia"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Acre"] = df_residencial_processed["Acre"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Amazonas"] = df_residencial_processed["Amazonas"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Roraima"] = df_residencial_processed["Roraima"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Pará"] = df_residencial_processed["Pará"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Amapá"] = df_residencial_processed["Amapá"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Tocantins"] = df_residencial_processed["Tocantins"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Maranhão"] = df_residencial_processed["Maranhão"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Piauí"] = df_residencial_processed["Piauí"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Ceará"] = df_residencial_processed["Ceará"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Rio Grande do Norte"] = df_residencial_processed["Rio Grande do Norte"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Paraíba"] = df_residencial_processed["Paraíba"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Pernambuco"] = df_residencial_processed["Pernambuco"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Alagoas"] = df_residencial_processed["Alagoas"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Sergipe"] = df_residencial_processed["Sergipe"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Bahia"] = df_residencial_processed["Bahia"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Minas Gerais"] = df_residencial_processed["Minas Gerais"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Espírito Santo"] = df_residencial_processed["Espírito Santo"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Rio de Janeiro"] = df_residencial_processed["Rio de Janeiro"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["São Paulo"] = df_residencial_processed["São Paulo"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Paraná"] = df_residencial_processed["Paraná"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Santa Catarina"] = df_residencial_processed["Santa Catarina"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Rio Grande do Sul"] = df_residencial_processed["Rio Grande do Sul"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Mato Grosso do Sul"] = df_residencial_processed["Mato Grosso do Sul"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Mato Grosso"] = df_residencial_processed["Mato Grosso"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Goiás"] = df_residencial_processed["Goiás"].astype("uint32")
# /tmp/ipykernel_12865/3757876696.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residencial_processed["Distrito Federal"] = df_residencial_processed["Distrito Federal"].astype("uint32")

# %% [markdown]
# ### Conferindo a troca de tipos

# %%
df_residencial_processed.dtypes
# Out:
# Empresa de Pesquisa Energética - EPE
# Rondônia               uint32
# Acre                   uint32
# Amazonas               uint32
# Roraima                uint32
# Pará                   uint32
# Amapá                  uint32
# Tocantins              uint32
# Maranhão               uint32
# Piauí                  uint32
# Ceará                  uint32
# Rio Grande do Norte    uint32
# Paraíba                uint32
# Pernambuco             uint32
# Alagoas                uint32
# Sergipe                uint32
# Bahia                  uint32
# Minas Gerais           uint32
# Espírito Santo         uint32
# Rio de Janeiro         uint32
# São Paulo              uint32
# Paraná                 uint32
# Santa Catarina         uint32
# Rio Grande do Sul      uint32
# Mato Grosso do Sul     uint32
# Mato Grosso            uint32
# Goiás                  uint32
# Distrito Federal       uint32
# dtype: object

# %% [markdown]
# ## Salvando os datasets tratados
# ### Eles serão salvos em .pkl (pickle)
# Essa extensão criada pelos desenvolvedores da biblioteca pandas salva os metadados dos datasets enquanto comprime seu tamanho de arquivo

# %%
df_residencial_processed.to_pickle(path = "./databases/processed/classes-consumoComercialPorUF.pkl")
